# %% [markdown]
# # SF Smart Mobility - Exploratory Data Analysis
#
# This notebook explores the transit and parking datasets to understand patterns and guide feature engineering.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime, timedelta

# Set style
sns.set_style('whitegrid')
plt.rcParams['figure.figsize'] = (12, 6)

# %matplotlib inline

# %% [markdown]
# ## 1. Transit Data Exploration

# %%
# TODO: Load transit data from 511 API
# transit_data = pd.read_csv('../data/raw/transit_data.csv')

# Explore dataset
# transit_data.head()
# transit_data.info()
# transit_data.describe()

# %% [markdown]
# ### Delay Patterns by Time

# %%
# Analyze delay patterns by hour of day
# transit_data['hour'] = pd.to_datetime(transit_data['timestamp']).dt.hour
# transit_data.groupby('hour')['delay_minutes'].mean().plot(kind='bar')
# plt.title('Average Transit Delay by Hour')
# plt.xlabel('Hour of Day')
# plt.ylabel('Average Delay (minutes)')
# plt.show()

# %% [markdown]
# ## 2. Parking Data Exploration

# %%
# TODO: Load parking data from DataSF
# parking_data = pd.read_csv('../data/raw/parking_data.csv')

# Explore dataset
# parking_data.head()
# parking_data.info()
# parking_data.describe()

# %% [markdown]
# ### Occupancy Patterns

# %%
# Analyze occupancy by neighborhood
# parking_data.groupby('neighborhood')['occupancy_rate'].mean().plot(kind='barh')
# plt.title('Average Parking Occupancy by Neighborhood')
# plt.xlabel('Occupancy Rate')
# plt.ylabel('Neighborhood')
# plt.show()

# %% [markdown]
# ## 3. Feature Correlation Analysis

# %%
# Create correlation matrix
# numeric_cols = transit_data.select_dtypes(include=[np.number]).columns
# correlation_matrix = transit_data[numeric_cols].corr()

# plt.figure(figsize=(10, 8))
# sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', center=0)
# plt.title('Feature Correlation Matrix')
# plt.show()

# %% [markdown]
# ## 4. Key Insights
#
# Document key findings here:
# - Transit delay patterns
# - Parking occupancy trends
# - Feature relationships
# - Data quality issues

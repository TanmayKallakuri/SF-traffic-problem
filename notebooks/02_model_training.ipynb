# %% [markdown]
# # Model Training - Transit & Parking Predictions
#
# This notebook trains and evaluates the ML models for transit delay and parking availability prediction.

# %%
import sys
sys.path.append('../src')

import pandas as pd
import numpy as np
from pathlib import Path

from transit import TransitDataFetcher, TransitFeatureEngine, TransitDelayPredictor
from parking import ParkingDataFetcher, ParkingFeatureEngine, ParkingAvailabilityPredictor

# %% [markdown]
# ## 1. Train Transit Delay Model

# %%
# Load transit data
# transit_data = pd.read_csv('../data/processed/transit_features.csv')

# Prepare features and target
# feature_cols = [...]
# X = transit_data[feature_cols]
# y = transit_data['delay_minutes']

# Train model
# transit_model = TransitDelayPredictor(model_type='random_forest')
# metrics = transit_model.train(X, y)
# print('Transit Model Metrics:', metrics)

# Save model
# transit_model.save(Path('../data/models/transit_delay_model.pkl'))

# %% [markdown]
# ## 2. Train Parking Availability Model

# %%
# Load parking data
# parking_data = pd.read_csv('../data/processed/parking_features.csv')

# Prepare features and targets
# feature_cols = [...]
# X = parking_data[feature_cols]
# y_availability = parking_data['availability_class']
# y_occupancy = parking_data['occupancy_rate']

# Train models
# parking_model = ParkingAvailabilityPredictor()
# availability_metrics = parking_model.train_availability(X, y_availability)
# occupancy_metrics = parking_model.train_occupancy(X, y_occupancy)

# print('Availability Metrics:', availability_metrics)
# print('Occupancy Metrics:', occupancy_metrics)

# Save model
# parking_model.save(Path('../data/models/parking_availability_model.pkl'))

# %% [markdown]
# ## 3. Model Evaluation & Visualization

# %%
# Feature importance analysis
# transit_importance = transit_model.get_feature_importance()
# print('Top 10 Transit Features:')
# print(transit_importance.head(10))

# %% [markdown]
# ## 4. Test Predictions

# %%
# Make sample predictions
# sample_transit = X.sample(5)
# predictions = transit_model.predict(sample_transit)
# print('Sample Transit Predictions:', predictions)
